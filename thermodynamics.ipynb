# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("thermo.csv",header=0, delimiter=r"\s+")

# %%
plt.plot(df['E_pair'])

# %%
np.mean(df['E_pair'])
# Out:
# -0.32011272215779213
